# %% [markdown]
# <a href="https://colab.research.google.com/github/SebastianCastillo180/MinTIC/blob/main/MINTIC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Clase MinTic ejercicios practicos**
#
# > Bloc con sangría
#
#
# https://www.youtube.com/watch?v=nk9PKnbjGcs
# **>>>> .**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelBinarizer, LabelEncoder
##import category_encoders

# %%
## Se incluye el dataframe de la carpeta drive a colab.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
## Ruta raiz
df="/content/drive/MyDrive"

# %%
Base = pd.read_excel("/content/drive/MyDrive/EjercicioTIC.xlsx")

# %% [markdown]
# # Visualizacion y Exploración de los Datos

# %%
### Se ejecuta nuestro DataFrame
Base.head()
# Out:
#     Region      Producto Vendedor  Ventas
# 0  Central    Accesorios    David    8287
# 1  Central    Accesorios    Karen    6909
# 2  Central  Dispositivos    David   11420
# 3  Central  Dispositivos    Karen   12948
# 4  Central      Sistemas    David   20098

# %%
### Se ejecuta los ultimos dos registros de nustro DataFrame
Base.tail(2)
# Out:
#    Region  Producto Vendedor  Ventas
# 16  Oeste  Sistemas    Kevin   32855
# 17  Oeste  Sistemas     Sara   23151

# %%
### Se evidencia la informacion de nuestro DataFrame
Base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Region    18 non-null     object
#  1   Producto  18 non-null     object
#  2   Vendedor  18 non-null     object
#  3   Ventas    18 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 704.0+ bytes

# %%
### Se evidencia la composicion de las columnas de nuestro DataFrame
Base.dtypes
# Out:
# Region      object
# Producto    object
# Vendedor    object
# Ventas       int64
# dtype: object

# %%
### Se evidencia la descripcion del campo ventas nuestro DataFrame
Base.describe()
# Out:
#              Ventas
# count     18.000000
# mean   13307.388889
# std     8153.055776
# min     4744.000000
# 25%     8410.250000
# 50%    10529.500000
# 75%    13491.750000
# max    32855.000000

# %%
### Se evidencia la columnas y filas de nuestro DataFrame
Base.shape
# Out:
# (18, 4)

# %%
### Se evidencia el nombre de nuestras columnas de nuestro DataFrame
Base.columns
# Out:
# Index(['Region', 'Producto', 'Vendedor', 'Ventas'], dtype='object')

# %%
print('Ejercicio 1: Mostrar las primeras filas del data frame')
print(Base.head(10))
# Out:
# Ejercicio 1: Mostrar las primeras filas del data frame
#     Region      Producto Vendedor  Ventas
# 0  Central    Accesorios    David    8287
# 1  Central    Accesorios    Karen    6909
# 2  Central  Dispositivos    David   11420
# 3  Central  Dispositivos    Karen   12948
# 4  Central      Sistemas    David   20098
# 5  Central      Sistemas    Karen   30633
# 6     Este    Accesorios      Ana    9323
# 7     Este    Accesorios    Lucas    7667
# 8     Este  Dispositivos      Ana   10348
# 9     Este  Dispositivos    Lucas    9312

# %%
print("Ejercicio 2: Calcula el total de ventas por region")
Ventas_region = Base.groupby('Region')['Ventas'].sum()
print(Ventas_region)
print('\n')
# Out:
# Ejercicio 2: Calcula el total de ventas por region
# Region
# Central    90295
# Este       63555
# Oeste      85683
# Name: Ventas, dtype: int64

# %%
print("Ejercicio 3: Filtramos el total de las ventas mayor a 15000")
Base_Filtrado = Base[Base['Ventas'] > 15000]
print(Base_Filtrado)
print('\n')
# Out:
# Ejercicio 3: Filtramos el total de las ventas mayor a 15000
#      Region  Producto Vendedor  Ventas
# 4   Central  Sistemas    David   20098
# 5   Central  Sistemas    Karen   30633
# 16    Oeste  Sistemas    Kevin   32855
# 17    Oeste  Sistemas     Sara   23151

# %%
print("Ejercicio 4: Filtramos el total de las ventas por el vendedor David")
Base_Filtrado_Vendedor = Base[Base['Vendedor'] == "David"]
print(Base_Filtrado_Vendedor)
print('\n')
# Out:
# Ejercicio 4: Filtramos el total de las ventas por el vendedor David
#     Region      Producto Vendedor  Ventas
# 0  Central    Accesorios    David    8287
# 2  Central  Dispositivos    David   11420
# 4  Central      Sistemas    David   20098

# %%
print("Ejercicio 5: Ordenes el DataFrame por ventas de forma ascendente")
Base_Ordenar_Asc = Base.sort_values(by='Ventas', ascending=True)
print(Base_Ordenar_Asc)
# Out:
# Ejercicio 5: Ordenes el DataFrame por ventas de forma ascendente
#      Region      Producto Vendedor  Ventas
# 12    Oeste    Accesorios    Kevin    4744
# 13    Oeste    Accesorios     Sara    5442
# 1   Central    Accesorios    Karen    6909
# 7      Este    Accesorios    Lucas    7667
# 0   Central    Accesorios    David    8287
# 15    Oeste  Dispositivos     Sara    8780
# 9      Este  Dispositivos    Lucas    9312
# 6      Este    Accesorios      Ana    9323
# 8      Este  Dispositivos      Ana   10348
# 14    Oeste  Dispositivos    Kevin   10711
# 2   Central  Dispositivos    David   11420
# 3   Central  Dispositivos    Karen   12948
# 11     Este      Sistemas    Lucas   13374
# 10     Este      Sistemas      Ana   13531
# 4   Central      Sistemas    David   20098
# 17    Oeste      Sistemas     Sara   23151
# 5   Central      Sistemas    Karen   30633
# 16    Oeste      Sistemas    Kevin   32855

# %%
print("Ejercicio 6: Ordenes el DataFrame por ventas de forma desendente")
Base_Ordenar_Desc = Base.sort_values(by='Ventas',ascending=False)
print(Base_Ordenar_Desc)
# Out:
# Ejercicio 6: Ordenes el DataFrame por ventas de forma desendente
#      Region      Producto Vendedor  Ventas
# 16    Oeste      Sistemas    Kevin   32855
# 5   Central      Sistemas    Karen   30633
# 17    Oeste      Sistemas     Sara   23151
# 4   Central      Sistemas    David   20098
# 10     Este      Sistemas      Ana   13531
# 11     Este      Sistemas    Lucas   13374
# 3   Central  Dispositivos    Karen   12948
# 2   Central  Dispositivos    David   11420
# 14    Oeste  Dispositivos    Kevin   10711
# 8      Este  Dispositivos      Ana   10348
# 6      Este    Accesorios      Ana    9323
# 9      Este  Dispositivos    Lucas    9312
# 15    Oeste  Dispositivos     Sara    8780
# 0   Central    Accesorios    David    8287
# 7      Este    Accesorios    Lucas    7667
# 1   Central    Accesorios    Karen    6909
# 13    Oeste    Accesorios     Sara    5442
# 12    Oeste    Accesorios    Kevin    4744

# %%
print("Ejercicio 7: Eliminar la columna vendedor")
Base_Eliminar_Vendedor = Base.drop(columns='Vendedor')
print(Base_Eliminar_Vendedor)
# Out:
# Ejercicio 7: Eliminar la columna vendedor
#      Region      Producto  Ventas
# 0   Central    Accesorios    8287
# 1   Central    Accesorios    6909
# 2   Central  Dispositivos   11420
# 3   Central  Dispositivos   12948
# 4   Central      Sistemas   20098
# 5   Central      Sistemas   30633
# 6      Este    Accesorios    9323
# 7      Este    Accesorios    7667
# 8      Este  Dispositivos   10348
# 9      Este  Dispositivos    9312
# 10     Este      Sistemas   13531
# 11     Este      Sistemas   13374
# 12    Oeste    Accesorios    4744
# 13    Oeste    Accesorios    5442
# 14    Oeste  Dispositivos   10711
# 15    Oeste  Dispositivos    8780
# 16    Oeste      Sistemas   32855
# 17    Oeste      Sistemas   23151

# %% [markdown]
# ## Crear un DataFrame

# %%
### Se realiza la creacion de nuestros datos creados
Data_Creada = {
    'id' : [1,2,3,4,5],
    'weight' : ['61.3','93.5','69.6','95.9','32.9'],
    'heigth' : ['Luisa','Andres','Paula','Esperanza','Luciana'],
    'age' : [27,34,22,56,8],
    'gender' : ['Femenino','Masculino','Femenino','Femenino','Femenino']
}
Data_Creada
# Out:
# {'id': [1, 2, 3, 4, 5],
#  'weight': ['61.3', '93.5', '69.6', '95.9', '32.9'],
#  'heigth': ['Luisa', 'Andres', 'Paula', 'Esperanza', 'Luciana'],
#  'age': [27, 34, 22, 56, 8],
#  'gender': ['Femenino', 'Masculino', 'Femenino', 'Femenino', 'Femenino']}

# %%
### Convertimos nuestros datos en un DataFrame
Creacion_DataFrame = pd.DataFrame(Data_Creada)
print('Se evidencia el detalle para la siguiente población')
print(Creacion_DataFrame)
# Out:
# Se evidencia el detalle para la siguiente población
#    id weight     heigth  age     gender
# 0   1   61.3      Luisa   27   Femenino
# 1   2   93.5     Andres   34  Masculino
# 2   3   69.6      Paula   22   Femenino
# 3   4   95.9  Esperanza   56   Femenino
# 4   5   32.9    Luciana    8   Femenino

# %% [markdown]
# # 1. El problema del negocio
#
# Una entidad bancaria contrata a una empresa de marketing encargada de contactar telefónicamente a posibles clientes para determinar si están interesados o no en adquirir un certificado de depósito a término con el banco.
#
# ¿Qué perfil tienen los clientes con mayor potencial de conversión?

# %% [markdown]
# #2. El set de datos
#
# La información recolectada por la empresa de mercadeo se encuentra en un archivo CSV (`dataset_banco.csv`) con 45215 filas y 17 columnas.
#
# Cada registro contiene 16 características (las primeras 16 columnas) y una categoría ("yes" o "no" dependiendo de si la persona está o no interesada en adquirir el producto). Las columnas son:
#
# 1. "age":  edad (numérica)
# 2. "job": tipo de trabajo (categórica: "admin.", "unknown", "unemployed", "management", "housemaid", "entrepreneur", "student", "blue-collar","self-employed", "retired", "technician", "services")
# 3. "marital": estado civil (categórica: "married", "divorced", "single")
# 4. "education": nivel educativo (categórica: "unknown", "secondary", "primary", "tertiary")
# 5. "default": si dejó de pagar sus obligaciones (categórica: "yes", "no")
# 6. "balance": saldo promedio anual en euros (numérica)
# 7. "housing": ¿tiene o no crédito hipotecario? (categórica: "yes", "no")
# 8. "loan": ¿tiene créditos de consumo? (categórica: "yes", "no")
# 9. "contact": medio a través del cual fue contactado (categórica: "unknown", "telephone", "cellular")
# 10. "day": último día del mes en el que fue contactada (numérica)
# 11. "month": último mes en el que fue contactada (categórica: "jan", "feb", "mar", ..., "nov", "dec")
# 12. "duration": duración (en segundos) del último contacto (numérica)
# 13. "campaign": número total de veces que fue contactada durante la campaña (numérica)
# 14. "pdays": número de días transcurridos después de haber sido contactado antes de la campaña actual (numérica. -1 indica que no fue contactado previamente)
# 15. "previous": número de veces que ha sido contactada antes de esta campaña (numérica)
# 16. "poutcome": resultado de la campaña de marketing anterior (categórica: "unknown", "other", "failure", "success")
# 17. "y": categoría ¿el cliente se suscribió a un depósito a término? (categórica: "yes", "no")

# %% [markdown]
# #3. Una primera mirada al dataset

# %%
import pandas as pd
import numpy as np
import numpy as np
import seaborn as sns
from sklearn.preprocessing import LabelBinarizer, LabelEncoder
##import category_encoders

# %%
data = pd.read_csv("/content/drive/MyDrive/dataset_banco.csv")

# %%
### Se ejecuta nuestro DataFrame
print(data.shape)
data.head()
# Out:
# (45215, 17)
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no   2143.0     yes   no
# 1   44    technician   single  secondary      no     29.0     yes   no
# 2   33  entrepreneur  married  secondary      no      2.0     yes  yes
# 3   47   blue-collar  married    unknown      no   1506.0     yes   no
# 4   33       unknown   single    unknown      no      1.0      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may     261.0         1   -1.0         0  unknown  no
# 1  unknown    5   may     151.0         1   -1.0         0  unknown  no
# 2  unknown    5   may      76.0         1   -1.0         0  unknown  no
# 3  unknown    5   may      92.0         1   -1.0         0  unknown  no
# 4  unknown    5   may     198.0         1   -1.0         0  unknown  no

# %%
### Se evidencia el nombre de nuestras columnas de nuestro DataFrame
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
### Se ejecuta los ultimos dos registros de nustro DataFrame
data.tail(5)
# Out:
#        age           job   marital  education default  balance housing loan  \
# 45210   51    technician   married   tertiary      no    825.0      no   no
# 45211   71       retired  divorced    primary      no   1729.0      no   no
# 45212   72       retired   married  secondary      no   5715.0      no   no
# 45213   57   blue-collar   married  secondary      no    668.0      no   no
# 45214   37  entrepreneur   married  secondary      no   2971.0      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 45210   cellular   17   nov     977.0         3   -1.0         0  unknown  yes
# 45211   cellular   17   nov     456.0         2   -1.0         0  unknown  yes
# 45212   cellular   17   nov    1127.0         5  184.0         3  success  yes
# 45213  telephone   17   nov     508.0         4   -1.0         0  unknown   no
# 45214   cellular   17   nov     361.0         2  188.0        11    other   no

# %%
### Se evidencia la informacion de nuestro DataFrame
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45215 entries, 0 to 45214
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45215 non-null  int64
#  1   job        45213 non-null  object
#  2   marital    45214 non-null  object
#  3   education  45214 non-null  object
#  4   default    45215 non-null  object
#  5   balance    45213 non-null  float64
#  6   housing    45215 non-null  object
#  7   loan       45215 non-null  object
#  8   contact    45215 non-null  object
#  9   day        45215 non-null  int64
#  10  month      45215 non-null  object
#  11  duration   45214 non-null  float64
#  12  campaign   45215 non-null  int64
#  13  pdays      45214 non-null  float64
#  14  previous   45215 non-null  int64
#  15  poutcome   45215 non-null  object
#  16  y          45215 non-null  object
# dtypes: float64(3), int64(4), object(10)
# memory usage: 5.9+ MB

# %%
### Se evidencia la composicion de las columnas de nuestro DataFrame
data.dtypes
# Out:
# age            int64
# job           object
# marital       object
# education     object
# default       object
# balance      float64
# housing       object
# loan          object
# contact       object
# day            int64
# month         object
# duration     float64
# campaign       int64
# pdays        float64
# previous       int64
# poutcome      object
# y             object
# dtype: object

# %%
### Se evidencia la descripcion del campo ventas nuestro DataFrame
data.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45215.000000   45213.000000  45215.000000  45214.000000  45215.000000
# mean      41.004711    1374.159866     15.805839    258.074357      2.763729
# std       12.036647    3924.255525      8.322473    257.605175      3.097910
# min       18.000000   -8019.000000      1.000000  -1389.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max      776.000000  527532.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45214.000000  45215.000000
# mean      40.192485      0.580383
# std      100.120622      2.303438
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %% [markdown]
# #4. Limpieza
#
# Realizaremos el proceso de limpieza teniendo en cuenta las situaciones más comunes:
#
# 1. Datos faltantes en algunas celdas
# 2. Columnas irrelevantes (que no responden al problema que queremos resolver)
# 3. Registros (filas) repetidos
# 4. Valores extremos (*outliers*) en el caso de las variables numéricas. Se deben analizar en detalle pues no necesariamente la solución es eliminarlos

# %%
data.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no   2143.0     yes   no
# 1   44    technician   single  secondary      no     29.0     yes   no
# 2   33  entrepreneur  married  secondary      no      2.0     yes  yes
# 3   47   blue-collar  married    unknown      no   1506.0     yes   no
# 4   33       unknown   single    unknown      no      1.0      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may     261.0         1   -1.0         0  unknown  no
# 1  unknown    5   may     151.0         1   -1.0         0  unknown  no
# 2  unknown    5   may      76.0         1   -1.0         0  unknown  no
# 3  unknown    5   may      92.0         1   -1.0         0  unknown  no
# 4  unknown    5   may     198.0         1   -1.0         0  unknown  no

# %%
### Se evidencia los datos nulos de nuesta DateFrame
data.isnull().sum()
# Out:
# age          0
# job          2
# marital      1
# education    1
# default      0
# balance      2
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     1
# campaign     0
# pdays        1
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %% [markdown]
# ## Isnull
# Isnull nos permite detectar datos nulos, simplificando este proceso independientemente de la dimensión de nuestra base de datos.

# %% [markdown]
# ## Notnull
# Una alternativa menos conocida es Notnull. Es la indicación lógica contraria, y la forma de llamar a la función es similar.

# %%
#agregamos la función isnull.
data.isnull()

#Si lo prefieres puedes usar:
data.notnull()
# Out:
#         age   job  marital  education  default  balance  housing  loan  \
# 0      True  True     True       True     True     True     True  True
# 1      True  True     True       True     True     True     True  True
# 2      True  True     True       True     True     True     True  True
# 3      True  True     True       True     True     True     True  True
# 4      True  True     True       True     True     True     True  True
# ...     ...   ...      ...        ...      ...      ...      ...   ...
# 45210  True  True     True       True     True     True     True  True
# 45211  True  True     True       True     True     True     True  True
# 45212  True  True     True       True     True     True     True  True
# 45213  True  True     True       True     True     True     True  True
# 45214  True  True     True       True     True     True     True  True
#
#        contact   day  month  duration  campaign  pdays  previous  poutcome  \
# ...

# %% [markdown]
# ## Dropna
# dropna() elimina las filas que contienen datos nulos, por tanto es muy útil para eliminar filas con varias datos nulos a la vez, ya que dichas filas no aportarían información significativa más que para unas cuantas variables.

# %%
### Se elimina los datos nulos
data2 = data.dropna()

# %%
print('Totalidad de los datos con nulos')
print(data.shape)
print('\n')
print('Totalidad de los datos sin nulos')
print(data2.shape)
# Out:
# Totalidad de los datos con nulos
# (45207, 17)
#
#
# Totalidad de los datos sin nulos
# (45199, 17)

# %%
### Llamamos nuevamente para identificar si tenemos nulos
data2.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
data2.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
data3 = data2.rename(columns={'age':'Edad','job':'Trabajo','marital':'Marital','education':'Educacion',
                                           'default':'Por_Defecto','balance':'Balance','housing':'Alojamiento','loan':'Prestamo',
                                          'contact':'Contacto','day':'Dia','month':'Mes','duration':'Duracion','campaign':'Camapaña',
                                          'pdays':'DiasP','previous':'Previa','poutcome':'Puchero'})
data3.columns
# Out:
# Index(['Edad', 'Trabajo', 'Marital', 'Educacion', 'Por_Defecto', 'Balance',
#        'Alojamiento', 'Prestamo', 'Contacto', 'Dia', 'Mes', 'Duracion',
#        'Camapaña', 'DiasP', 'Previa', 'Puchero', 'y'],
#       dtype='object')

# %%
### Conteo de los niveles en las diferentes columnas categóricas
cols_cat = ['job','marital','education','default','housing','loan','contact','month','poutcome','y',]

for col in cols_cat:
  print(f'columna {col}: {data2[col].nunique()} subniveles')
# Out:
# columna job: 18 subniveles
# columna marital: 6 subniveles
# columna education: 10 subniveles
# columna default: 2 subniveles
# columna housing: 2 subniveles
# columna loan: 6 subniveles
# columna contact: 5 subniveles
# columna month: 12 subniveles
# columna poutcome: 6 subniveles
# columna y: 2 subniveles

# %%
Media = data2['pdays'].mean()
print("El promedio para el campo DiasP corresponde",Media)
# Out:
# El promedio para el campo DiasP corresponde 40.17976061417288

# %%
## Se realiza un histograma para identificar la columna DiasP
plt.hist(data3['DiasP'], bins=20, color="skyblue", edgecolor='black', alpha=0.9)

## Para el histograma podemos la media en color rojo
plt.axvline(Media, color='red', linestyle='dashed',linewidth=1)

data3.groupby("DiasP").size()
# Out:
# DiasP
# -1.0      36946
#  1.0         15
#  2.0         37
#  3.0          1
#  4.0          2
#           ...
#  838.0        1
#  842.0        1
#  850.0        1
#  854.0        1
#  871.0        1
# Length: 559, dtype: int64

# %% [markdown]
# # 5. Errores tipográficos en el caso de las variables categóricas
#
# Al final de este proceso de limpieza deberíamos tener un set de datos **íntegro**, listo para la fase de Análisis Exploratorio.

# %%
PromedioTodasVariables =data2.groupby(['education','marital','y']).mean()
PromedioTodasVariables
###PromedioTodasVariables.drop(["age","day","duration","campaign", "pdays"], axis=1)
# Out:
# <ipython-input-81-7c465647ca6e>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   PromedioTodasVariables =data2.groupby(['education','marital','y']).mean()
#                               age      balance        day    duration  \
# education marital  y
# Primary   married  no   48.000000   680.000000  15.000000  387.000000
#                    yes  50.000000   461.000000  15.000000  651.000000
# SECONDARY married  no   46.666667  2084.000000  15.000000  223.666667
# Secondary divorced no   45.000000   660.000000  15.000000   71.000000
# Tertiary  married  no   43.000000  8016.000000  15.000000  422.000000
# UNK       married  no   40.000000   161.500000  15.000000  217.000000
# primary   div.     no   48.000000   -18.000000   8.000000   11.000000
# ...

# %% [markdown]
# ## 4.1 Datos faltantes
#
# Acá comenzamos a ver que los datos no están completos, pues no todas las columnas tienen la misma cantidad de registros.
#
# El número total de registros debería ser 45.215. Sin embargo columnas como "job", "marital", "education", "balance", "duration" y "pdays".
#
# Por ser tan pocos los datos  faltantes optaremos por eliminar las filas correspondientes:

# %%
### Eliminar filas con "Age" > 100
print(f'Tamaño del set antes de eliminar registros de edad: {data2.shape}')
data2 = data2.drop(data2[data2['age'] > 100].index)
print(f'Tamaño del set despues de eliminar registros de duraciín: {data2.shape}')
# Out:
# Tamaño del set antes de eliminar registros de edad: (45199, 17)
# Tamaño del set despues de eliminar registros de duraciín: (45199, 17)

# %%
### Eliminar filas con "duration" < 0
### print(f'Tamaño del set antes de eliminar registros de duración: {data2.shape}')
### data2 = data2.drop(data2[data2['duration'] > 0].index)
### print(f'Tamaño del set despues de eliminar registros de duraciín: {data2.shape}')

# %% [markdown]
# ##4.2 Columnas irrelevantes
#
# Una columna irrelevante puede ser:
#
# - **Una columna que no contiene información relevante para el problema que queremos resolver**. Por ejemplo en este caso podría ser una columna que no guarde relación con el posible perfil del cliente (deporte favorito, hobbies, comida favorita, etc.)
# - **Una columna categórica pero con un sólo nivel**. Por ejemplo si en la columna "job" solo tuviésemos el nivel "unknown".
# - **Una columna numérica pero con un sólo valor**. Por ejemplo si en la columna "edad" todos los valores fuesen iguales a 50.
# - **Columnas con información redundante**. Por ejemplo si además de las columnas "month" y "day" tuviésemos la columna "month-day", resultado de combinar las dos anteriores.
#
# Si tenemos la duda de si alguna columna puede ser relevante o no lo mejor es dejarla (y más adelante en posteriores etapas podremos darnos cuenta de si se debe preservar o no).
#
# En este caso todas las columnas pueden resultar relevantes, pero debemos verificar que no haya columnas categóricas con un sólo nivel, o columnas numéricas con un sólo valor:

# %%
### Identifcamos el comportamiento de nuestro DataFrame las cuales contienen texto

cols_cat = ['job','marital','education','default',
            'housing','loan','contact','month','poutcome','y']

fig,ax = plt.subplots(nrows=10, ncols=1, figsize=(10,30))
fig.subplots_adjust(hspace=1)

for i, col in enumerate(cols_cat):
  sns.countplot(x=col, data=data2, ax=ax[i])

  ax[i].set_title(col)
  ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation = 30)
# Out:
# <ipython-input-88-4d17ee2f44f9>:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation = 30)
# <ipython-input-88-4d17ee2f44f9>:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation = 30)
# <ipython-input-88-4d17ee2f44f9>:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation = 30)
# <ipython-input-88-4d17ee2f44f9>:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation = 30)
# <ipython-input-88-4d17ee2f44f9>:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation = 30)
# ...

# %%
## Generamos un diccionario para remplazar los valores que generan ruido de la columna job.

print(data2['job'].unique())
data2['job'] = data2['job'].str.replace('Management','management', regex=False)
print(data2['job'].unique())

print(data2['job'].unique())
data2['job'] = data2['job'].str.replace('MANAGEMENT','management', regex=False)
print(data2['job'].unique())

print(data2['job'].unique())
data2['job'] = data2['job'].str.replace('admin.','administrative', regex=False)
print(data2['job'].unique())

print(data2['job'].unique())
data2['job'] = data2['job'].str.replace('Services','services', regex=False)
print(data2['job'].unique())

print(data2['job'].unique())
data2['job'] = data2['job'].str.replace('Self-employed','self-employed', regex=False)
print(data2['job'].unique())

print(data2['job'].unique())
data2['job'] = data2['job'].str.replace('Retired','retired', regex=False)
print(data2['job'].unique())

# %%
## Generamos un diccionario para remplazar los valores que generan ruido de la columna marital.

print(data2['marital'].unique())
data2['marital'] = data2['marital'].str.replace('div.','divorced', regex=False)
print(data2['marital'].unique())

print(data['marital'].unique())
data2['marital'] = data2['marital'].str.replace('Single','single', regex=False)
print(data2['marital'].unique())

print(data['marital'].unique())
data2['marital'] = data2['marital'].str.replace('DIVORCED','divorced', regex=False)
print(data2['marital'].unique())
# Out:
# ['married' 'single' 'divorced' 'DIVORCED']
# ['married' 'single' 'divorced' 'DIVORCED']
# ['married' 'single' 'div.' 'divorced' 'DIVORCED' 'Single' nan]
# ['married' 'single' 'divorced' 'DIVORCED']
# ['married' 'single' 'div.' 'divorced' 'DIVORCED' 'Single' nan]
# ['married' 'single' 'divorced']

# %%
## Generamos un diccionario para remplazar los valores que generan ruido de la columna education.

print(data2['education'].unique())
data2['education'] = data2['education'].str.replace('sec.','secondary', regex=False)
print(data2['education'].unique())

print(data2['education'].unique())
data2['education'] = data2['education'].str.replace('SECONDARY','secondary', regex=False)
print(data2['education'].unique())

print(data2['education'].unique())
data2['education'] = data2['education'].str.replace('Secondary','secondary', regex=False)
print(data2['education'].unique())

print(data2['education'].unique())
data2['education'] = data2['education'].str.replace('Tertiary','tertiary', regex=False)
print(data2['education'].unique())

print(data2['education'].unique())
data2['education'] = data2['education'].str.replace('UNK','unknown', regex=False)
print(data2['education'].unique())

print(data2['education'].unique())
data2['education'] = data2['education'].str.replace('Primary','primary', regex=False)
print(data2['education'].unique())
# Out:
# ['tertiary' 'secondary' 'unknown' 'primary' 'SECONDARY']
# ['tertiary' 'secondary' 'unknown' 'primary' 'SECONDARY']
# ['tertiary' 'secondary' 'unknown' 'primary' 'SECONDARY']
# ['tertiary' 'secondary' 'unknown' 'primary']
# ['tertiary' 'secondary' 'unknown' 'primary']
# ['tertiary' 'secondary' 'unknown' 'primary']
# ['tertiary' 'secondary' 'unknown' 'primary']
# ['tertiary' 'secondary' 'unknown' 'primary']
# ['tertiary' 'secondary' 'unknown' 'primary']
# ['tertiary' 'secondary' 'unknown' 'primary']
# ['tertiary' 'secondary' 'unknown' 'primary']
# ['tertiary' 'secondary' 'unknown' 'primary']

# %%
## Generamos un diccionario para remplazar los valores que generan ruido de la columna loan.

print(data2['loan'].unique())
data2['loan'] = data2['loan'].str.replace('No','no', regex=False)
print(data2['loan'].unique())

print(data2['loan'].unique())
data2['loan'] = data2['loan'].str.replace('NO','no', regex=False)
print(data2['loan'].unique())

print(data2['loan'].unique())
data2['loan'] = data2['loan'].str.replace('Yes','yes', regex=False)
print(data2['loan'].unique())

print(data2['loan'].unique())
data2['loan'] = data2['loan'].str.replace('YES','yes', regex=False)
print(data2['loan'].unique())
# Out:
# ['no' 'yes']
# ['no' 'yes']
# ['no' 'yes']
# ['no' 'yes']
# ['no' 'yes']
# ['no' 'yes']
# ['no' 'yes']
# ['no' 'yes']

# %%
## Generamos un diccionario para remplazar los valores que generan ruido de la columna contact.

print(data2['contact'].unique())
data2['contact'] = data2['contact'].str.replace('mobile','cellular', regex=False)
print(data2['contact'].unique())

print(data2['contact'].unique())
data2['contact'] = data2['contact'].str.replace('teletelephone','telephone', regex=False)
print(data2['contact'].unique())
# Out:
# ['unknown' 'cellular' 'teletelephone' 'telephone']
# ['unknown' 'cellular' 'teletelephone' 'telephone']
# ['unknown' 'cellular' 'teletelephone' 'telephone']
# ['unknown' 'cellular' 'telephone']

# %%
## Generamos un diccionario para remplazar los valores que generan ruido de la columna poutcome.

print(data2['poutcome'].unique())
data2['poutcome'] = data2['poutcome'].str.replace('Success','success', regex=False)
print(data2['poutcome'].unique())

print(data2['poutcome'].unique())
data2['poutcome'] = data2['poutcome'].str.replace('UNK','unknown', regex=False)
print(data2['poutcome'].unique())
# Out:
# ['unknown' 'failure' 'other' 'success']
# ['unknown' 'failure' 'other' 'success']
# ['unknown' 'failure' 'other' 'success']
# ['unknown' 'failure' 'other' 'success']

# %%
### Se realiza las graficas de los subniveles de cada variable categoricas las cuales se les realizo la limpieza.
cols_cat = ['job','marital','education','default',
            'housing','loan','contact','month','poutcome','y']

fig,ax = plt.subplots(nrows=10, ncols=1, figsize=(10,30))
fig.subplots_adjust(hspace=1)

for i, col in enumerate(cols_cat):
  sns.countplot(x=col, data=data2, ax=ax[i])

  ax[i].set_title(col)
  ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation = 30)
# Out:
# <ipython-input-124-4d17ee2f44f9>:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation = 30)
# <ipython-input-124-4d17ee2f44f9>:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation = 30)
# <ipython-input-124-4d17ee2f44f9>:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation = 30)
# <ipython-input-124-4d17ee2f44f9>:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation = 30)
# <ipython-input-124-4d17ee2f44f9>:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation = 30)
# ...

# %%
### Nevamente sacamos las variables de nuestro dataFrame con la información limpia.
PromedioTodasVariablesDos =data2.groupby(['marital','education','y']).mean()
PromedioTodasVariablesDos
###PromedioTodasVariables.drop(["age","day","duration","campaign", "pdays"], axis=1)
# Out:
# <ipython-input-128-ba7b5a7448de>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   PromedioTodasVariablesDos =data2.groupby(['marital','education','y']).mean()
#                               age      balance        day    duration  \
# marital  education y
# divorced primary   no   50.165123  1084.950617  14.955247  222.379630
#                    yes  59.778846  1466.230769  16.211538  588.711538
#          secondary no   43.891710   863.637049  15.782229  218.034907
#                    yes  47.212329  1241.263699  15.575342  599.640411
#          tertiary  no   45.196372  1579.911672  16.440852  215.452681
#                    yes  46.886700  2456.753695  15.093596  561.802956
#          unknown   no   49.434483  1308.944828  15.434483  233.896552
# ...

# %%
### Guardamos nuestro archivo en el driver con su respectiva limpieza
data2.to_excel('MINTIC.xlsx')
from google.colab import files
files.download('MINTIC.xlsx')

# %% [markdown]
# ## Responde a las siguientes preguntas de negocio
#
# 1. ¿Cuál es la edad promedio de los clientes interesados en adquirir un certificado de depósito?
# 2. En una gráfica, establece la diferencia de ingresos entre clientes interesados y no interesados en el certificado de depósito
# 3. En un gráfico de barras, establece la distribución de género entre clientes interesados en el certificado de depósito
# 4. ¿Cuál es el nivel educativo predominante entre clientes interesados en el certificado de depósito?
# 5. ¿Cuál es la relación entre estado civil vs el interés en adquirir el certificado de depósito?
# 6. ¿Cuál es la distribución del medio de contacto más frecuente de los clientes interesados en adquirir el certificado de depósito?
# 7. En un gráfico de barras horizontales responde, ¿Cuál es el tipo de ocupación de los clientes interesados en adquirir el certificado de depósito?
# 8. ¿Cuál es la frecuencia de contacto con los clientes interesados antes de la conversión?
# 9. ¿Cuál es el patrón temporal en los contactos que conducen a una mayor conversión de clientes?

# %%
## 1. ¿Cuál es la edad promedio de los clientes interesados en adquirir un certificado de depósito?
Edad_Promedio_Interesado = data2[data2['y'] == 'yes']['age'].mean()
print("El promedio de los clientes interesados corresponde",Edad_Promedio_Interesado)
# Out:
# El promedio de los clientes interesados corresponde 41.80616490166415

# %%
## 2. En una gráfica, establece la diferencia de ingresos entre clientes interesados y no interesados en el certificado de depósito
sns.boxplot(x='y', y='balance', data=data)
plt.title('ssdsd')
plt.show()

# %%
### 4.¿Cuál es el nivel educativo predominante entre clientes interesados en el certificado de depósito?
print(data2.groupby("education").size())
# Out:
# education
# Primary          2
# SECONDARY        3
# Secondary        1
# Tertiary         1
# UNK              2
# primary       6848
# sec.             2
# secondary    23192
# tertiary     13301
# unknown       1855
# dtype: int64

# %%
##Promedio = Base_Banco2.groupby(["education", "y"])

###Promedio = Base_Banco2.groupby(["education", "y"]).mean()
Prueba =data2.groupby(['education','y']).mean()
Prueba.drop(["age","day","duration","campaign", "pdays"], axis=1)
# Out:
# <ipython-input-47-5ffeb02df456>:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   Prueba =data2.groupby(['education','y']).mean()
#                    balance  previous
# education y
# Primary   no    680.000000  0.000000
#           yes   461.000000  0.000000
# SECONDARY no   2084.000000  0.000000
# Secondary no    660.000000  0.000000
# Tertiary  no   8016.000000  0.000000
# UNK       no    161.500000  0.000000
# primary   no   1194.038345  0.435054
#           yes  1858.748727  1.054329
# sec.      no    270.000000  0.000000
# secondary no   1139.411166  0.499976
#           yes  1499.585475  1.141983
# tertiary  no   1697.270653  0.557934
#           yes  2108.313283  1.253634
# unknown   no   1417.585153  0.403618
#           yes  2232.027778  1.031746

# %%
print("Ejercicio 2: Calcula el total de ventas por region")
Ventas = data.groupby('education')['y'].sum()
print(Ventas)
print('\n')
# Out:
# Ejercicio 2: Calcula el total de ventas por region
# education
# Primary                                                  yesno
# SECONDARY                                               nonono
# Secondary                                                   no
# Tertiary                                                    no
# UNK                                                       nono
# primary      nonononononononononononononononononononononono...
# sec.                                                      nono
# secondary    nonononononononononononononononononononononono...
# tertiary     nonononononononononononononononononononononono...
# unknown      nonononononononononononononononononononononono...
# Name: y, dtype: object

# %%
## 4. ¿Cuál es la relación entre estado civil vs el interés en adquirir el certificado de depósito?
Prueba2 =Base_Banco2.groupby(['marital','y']).mean()
Prueba2.drop(["age","day","duration","campaign", "pdays"], axis=1)

# %%
Base_Banco.head()
